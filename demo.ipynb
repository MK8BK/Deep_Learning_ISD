# %% [markdown]
# # Demonstration du reseau neuronal & Applications

# %% [markdown]
# ## Precisions lors 1200 iterations sur des batch de 32 images equilibrees par classe
#
# <img src="docs/samples/Figure_1.png">

# %% [markdown]
# ## Exemples concrets

# %%
import pickle
#from src.Trainer import *
#from Utilities import *
from src.LoadData import *
from src.Utilities import *
import matplotlib.pyplot as plt

# %%
f = open("models/nn.pkl", 'rb')
nn = pickle.load(f)
f.close()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <cell line: 2>()
#       1 f = open("models/nn.pkl", 'rb')
# ----> 2 nn = pickle.load(f)
#       3 f.close()
#
# ModuleNotFoundError: No module named 'NeuralNetwork'

# %%
titles = []
for i in range(len(batch)): 
    x, nim, im , y= load_image(batch[i], CLASSES)
    p = nn.forward(nim)
    titles.append(predictions(p)[0])
image_grid(imgs, titles=titles)
