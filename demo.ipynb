# %% [markdown]
# # Demonstration du reseau neuronal & Applications

# %% [markdown]
# ## Precisions lors 1200 iterations sur des batch de 32 images equilibrees par classe
#
# <img src="docs/samples/Figure_1.png">

# %% [markdown]
# ## Exemples concrets

# %%
import pickle
from Trainer import *
from Utilities import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <cell line: 2>()
#       1 import pickle
# ----> 2 from Trainer import *
#       3 from Utilities import *
#
# ModuleNotFoundError: No module named 'Trainer'

# %%
f = open("nn.pkl", 'rb')
nn = pickle.load(f)
f.close()

# %%
batch = make_random_batch("./EMNIST_DATA_SET/", 32, CLASSES, equilibrium=True)
imgs = [load_pil_image(f) for f in batch]
image_grid(imgs, titles=[" "]*len(batch))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 batch = make_random_batch("./EMNIST_DATA_SET/", 32, CLASSES, equilibrium=True)
#       2 imgs = [load_pil_image(f) for f in batch]
#       3 image_grid(imgs, titles=[" "]*len(batch))
#
# NameError: name 'make_random_batch' is not defined

# %%
titles = []
for i in range(len(batch)): 
    x, nim, im = load_image(batch[i], CLASSES)
    p = nn.forward(nim)
    titles.append(predictions(p)[0])
image_grid(imgs, titles=titles)
